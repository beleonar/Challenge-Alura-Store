# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
facturacion_tienda1 = tienda1['Precio'].sum()
facturacion_tienda2 = tienda2['Precio'].sum()
facturacion_tienda3 = tienda3['Precio'].sum()
facturacion_tienda4 = tienda4['Precio'].sum()

print(f"Tienda 1: ${facturacion_tienda1:,.0f}")
print(f"Tienda 2: ${facturacion_tienda2:,.0f}")
print(f"Tienda 3: ${facturacion_tienda3:,.0f}")
print(f"Tienda 4: ${facturacion_tienda4:,.0f}")
# Out:
# Tienda 1: $1,150,880,400
# Tienda 2: $1,116,343,500
# Tienda 3: $1,098,019,600
# Tienda 4: $1,038,375,700

# %%
facturaciones = {
    'Tienda 1': facturacion_tienda1,
    'Tienda 2': facturacion_tienda2,
    'Tienda 3': facturacion_tienda3,
    'Tienda 4': facturacion_tienda4
}
tienda_mayor_facturacion = max(facturaciones, key=facturaciones.get)
print(f"Tienda con MAYOR facturación: {tienda_mayor_facturacion}")
# Out:
# Tienda con MAYOR facturación: Tienda 1

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_por_categoria = todas_tiendas['Categoría del Producto'].value_counts()
print("Ventas por categoría (cantidad):")
print(ventas_por_categoria)
# Out:
# Ventas por categoría (cantidad):
# Categoría del Producto
# Muebles                    1886
# Electrónicos               1772
# Juguetes                   1290
# Electrodomésticos          1149
# Deportes y diversión       1113
# Instrumentos musicales      753
# Libros                      742
# Artículos para el hogar     730
# Name: count, dtype: int64

# %%
monto_por_categoria = todas_tiendas.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
print("\nMonto facturado por categoría:")
print(monto_por_categoria)
# Out:
# Monto facturado por categoría:
# Categoría del Producto
# Electrónicos               1.660576e+09
# Electrodomésticos          1.324751e+09
# Muebles                    7.576610e+08
# Instrumentos musicales     3.487726e+08
# Deportes y diversión       1.429777e+08
# Juguetes                   7.360440e+07
# Artículos para el hogar    5.757980e+07
# Libros                     3.769610e+07
# Name: Precio, dtype: float64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_tienda1 = tienda1['Calificación'].mean()
calificacion_tienda2 = tienda2['Calificación'].mean()
calificacion_tienda3 = tienda3['Calificación'].mean()
calificacion_tienda4 = tienda4['Calificación'].mean()

print(f"Tienda 1: {calificacion_tienda1:.1f}/5")
print(f"Tienda 2: {calificacion_tienda2:.1f}/5")
print(f"Tienda 3: {calificacion_tienda3:.1f}/5")
print(f"Tienda 4: {calificacion_tienda4:.1f}/5")
# Out:
# Tienda 1: 4.0/5
# Tienda 2: 4.0/5
# Tienda 3: 4.0/5
# Tienda 4: 4.0/5

# %%
calificaciones = {
    'Tienda 1': calificacion_tienda1,
    'Tienda 2': calificacion_tienda2,
    'Tienda 3': calificacion_tienda3,
    'Tienda 4': calificacion_tienda4
}
tienda_mejor_calificacion = max(calificaciones, key=calificaciones.get)
print(f"Tienda con MEJOR calificación: {tienda_mejor_calificacion}")
# Out:
# Tienda con MEJOR calificación: Tienda 3

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
ventas_por_producto = todas_tiendas['Producto'].value_counts()

print("Productos más vendidos:")
print(ventas_por_producto.head(3))

print("\nProductos menos vendidos:")
print(ventas_por_producto.tail(3))
# Out:
# Productos más vendidos:
# Producto
# Mesa de noche                210
# Carrito de control remoto    206
# Microondas                   206
# Name: count, dtype: int64
#
# Productos menos vendidos:
# Producto
# Mochila                      163
# Auriculares con micrófono    158
# Celular ABXY                 157
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_tienda1 = tienda1['Costo de envío'].mean()
envio_tienda2 = tienda2['Costo de envío'].mean()
envio_tienda3 = tienda3['Costo de envío'].mean()
envio_tienda4 = tienda4['Costo de envío'].mean()

print(f"Tienda 1: ${envio_tienda1:,.0f}")
print(f"Tienda 2: ${envio_tienda2:,.0f}")
print(f"Tienda 3: ${envio_tienda3:,.0f}")
print(f"Tienda 4: ${envio_tienda4:,.0f}")
# Out:
# Tienda 1: $26,019
# Tienda 2: $25,216
# Tienda 3: $24,806
# Tienda 4: $23,459

# %%
envios = {
    'Tienda 1': envio_tienda1,
    'Tienda 2': envio_tienda2,
    'Tienda 3': envio_tienda3,
    'Tienda 4': envio_tienda4
}
tienda_menor_envio = min(envios, key=envios.get)
print(f"Tienda con MENOR costo de envío: {tienda_menor_envio}")
# Out:
# Tienda con MENOR costo de envío: Tienda 4

# %%
print("\n" + "="*50)
print("RECOMENDACIÓN FINAL PARA EL SEÑOR JUAN")
print("="*50)

# Crear un sistema de puntuación
puntuaciones = {'Tienda 1': 0, 'Tienda 2': 0, 'Tienda 3': 0, 'Tienda 4': 0}

# Puntos por facturación (más puntos para menor facturación - tienda a vender)
orden_facturacion = sorted(facturaciones.items(), key=lambda x: x[1])
for i, (tienda, _) in enumerate(orden_facturacion):
    puntuaciones[tienda] += i

# Puntos por calificación (más puntos para peor calificación - tienda a vender)
orden_calificacion = sorted(calificaciones.items(), key=lambda x: x[1])
for i, (tienda, _) in enumerate(orden_calificacion):
    puntuaciones[tienda] += i
# Out:
# ...
# RECOMENDACIÓN FINAL PARA EL SEÑOR JUAN
# ...

# %%
orden_envio = sorted(envios.items(), key=lambda x: x[1], reverse=True)
for i, (tienda, _) in enumerate(orden_envio):
    puntuaciones[tienda] += i

print("\nPUNTUACIÓN FINAL (mayor puntuación = mejor candidata para vender):")
for tienda, puntuacion in sorted(puntuaciones.items(), key=lambda x: x[1], reverse=True):
    print(f"{tienda}: {puntuacion} puntos")

tienda_recomendada = max(puntuaciones, key=puntuaciones.get)
print(f"\n RECOMENDACIÓN: VENDER LA {tienda_recomendada}")

# Justificación detallada
print(f"\nJUSTIFICACIÓN:")
print(f"- Facturación: {tienda_recomendada} tiene la {list(orden_facturacion).index((tienda_recomendada, facturaciones[tienda_recomendada])) + 1}ª mayor facturación")
print(f"- Calificación: {tienda_recomendada} tiene la {list(orden_calificacion).index((tienda_recomendada, calificaciones[tienda_recomendada])) + 1}ª mejor calificación")
print(f"- Costo de envío: {tienda_recomendada} tiene el {list(orden_envio).index((tienda_recomendada, envios[tienda_recomendada])) + 1}º mayor costo de envío")
# Out:
# PUNTUACIÓN FINAL (mayor puntuación = mejor candidata para vender):
# Tienda 3: 6 puntos
# Tienda 2: 5 puntos
# Tienda 4: 4 puntos
# Tienda 1: 3 puntos
#
#  RECOMENDACIÓN: VENDER LA Tienda 3
#
# JUSTIFICACIÓN:
# - Facturación: Tienda 3 tiene la 2ª mayor facturación
# - Calificación: Tienda 3 tiene la 4ª mejor calificación
# - Costo de envío: Tienda 3 tiene el 3º mayor costo de envío
